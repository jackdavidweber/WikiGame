# %%
import pandas as pd

# %% [markdown]
# We have a csv that we manually collected from [The Wiki Game](https://www.thewikigame.com/group) with the paths of 30 Wikipedia Game winners. These are the paths taken by real human players on the website. Let's read these in and make them into an easier format for our program to process.

# %%
human_games_df = pd.read_csv("human_games.csv")

# %%
human_paths = list(human_games_df['Path'].values)

# %%
for i in range(len(human_paths)):
    human_paths[i] = human_paths[i].split("\xa0→\xa0")

# %%
human_paths[:4]
# Out:
# [['Romance languages',
#   'Africa',
#   'Asia',
#   'Pacific Rim',
#   'Australia',
#   'Great Barrier Reef'],
#  ['Natalie Portman',
#   'United States nationality law',
#   'American Samoa',
#   'Samoan language',
#   'Language family',
#   'Proto-language',
#   'Proto-Indo-European language'],
#  ['IBM', 'Artificial intelligence', 'Facial recognition system', 'Human eye'],
#  ['Academy Awards',
#   'American Broadcasting Company',
#   'Television network',
#   'Telecommunications network']]

# %% [markdown]
# Great! We can see that the first item in each sublist is the source Wikipedia Article. The last item in each sublist is the target Wikipedia Article. Let's make a list of both using list comprehensions.

# %%
sources = [x[0] for x in human_paths]
targets = [x[-1] for x in human_paths]

print(f"First four sources: {sources[:4]}")
print(f"First four targets: {targets[:4]}")
# Out:
# First four sources: ['Romance languages', 'Natalie Portman', 'IBM', 'Academy Awards']
# First four targets: ['Great Barrier Reef', 'Proto-Indo-European language', 'Human eye', 'Telecommunications network']

# %% [markdown]
# Now let's use the code we wrote in WikipediaSearch to see how the semantic and random player compare to the human players. We set a limit of 25 clicks for both players. The wikipedia game has a 120 second time limit and we figured that it would be very difficult for a human to click 25 links in that amount of time if they were playing any real strategy

# %%
from WikipediaSearch import WikipediaSearch

semantic_player = WikipediaSearch("semantic")
random_player = WikipediaSearch("random")

semantic_paths = []
random_paths = []
for i in range(len(sources)):
    print(f"Source: {sources[i]}, Target: {targets[i]}")

    semantic_path = semantic_player.search(sources[i], targets[i], limit=25)
    semantic_paths.append(semantic_path)

    random_path = random_player.search(sources[i], targets[i], limit=25)
    random_paths.append(random_path)
    
    print(f"Semantic path length: {len(semantic_path)}")
    print(f"Random path length: {len(random_path)}")
    print()
# Out:
# Source: Romance languages, Target: Great Barrier Reef
# Semantic path length: 3
# Random path length: 0
#
# Source: Natalie Portman, Target: Proto-Indo-European language
# Semantic path length: 0
# Random path length: 0
#
# Source: IBM, Target: Human eye
# Semantic path length: 24
# Random path length: 0
#
# Source: Academy Awards, Target: Telecommunications network
# Semantic path length: 12
# Random path length: 0
#
# Source: Folk music, Target: John Krasinski
# Semantic path length: 0
# Random path length: 0
#
# Source: Kindergarten, Target: John Calvin
# Semantic path length: 4
# Random path length: 0
#
# Source: Glucose, Target: Nintendo Entertainment System
# Semantic path length: 5
# Random path length: 0
#
# Source: Planet, Target: BBC One
# Semantic path length: 3
# Random path length: 0
#
# Source: Text messaging, Target: Resurrection of Jesus
# Semantic path length: 8
# Random path length: 0
#
# Source: Charles Bronson, Target: Role-playing game
# Semantic path length: 8
# Random path length: 0
#
# Source: Wavelength, Target: Kelly Clarkson
# Semantic path length: 0
# Random path length: 0
#
# Source: Germanium, Target: Science
# Semantic path length: 6
# Random path length: 0
#
# Source: The Doors, Target: Nobel Prize in Physiology or Medicine
# Semantic path length: 0
# Random path length: 0
#
# Source: Lead, Target: DNA replication
# Semantic path length: 7
# Random path length: 0
#
# Source: Jacqueline Kennedy Onassis, Target: Humanism
# Semantic path length: 5
# Random path length: 0
#
# Source: Marco Polo, Target: Atmosphere
# Semantic path length: 11
# Random path length: 0
#
# Source: Diabetes mellitus, Target: Health care
# Semantic path length: 3
# Random path length: 0
#
# Source: Astronaut, Target: Family
# Semantic path length: 23
# Random path length: 0
#
# Source: Minnesota, Target: Hayley Williams
# Semantic path length: 0
# Random path length: 0
#
# Source: Sheep, Target: Bruce Lee
# Semantic path length: 0
# Random path length: 0
#
# Source: Fishing, Target: Drug
# Semantic path length: 11
# Random path length: 0
#
# Source: International Olympic Committee, Target: Glass
# Semantic path length: 10
# Random path length: 0
#
# Source: Zhang Ziyi, Target: Southeast Europe
# Semantic path length: 11
# Random path length: 0
#
# Source: SWAT, Target: New Testament
# Semantic path length: 6
# Random path length: 0
#
# Source: Wheat, Target: Doctorate
# Semantic path length: 5
# Random path length: 0
#
# Source: Sarah Palin, Target: Ship
# Semantic path length: 0
# Random path length: 0
#
# Source: Tool, Target: Sunlight
# Semantic path length: 3
# Random path length: 0
#
# Source: Education, Target: Extraterrestrial life
# Semantic path length: 9
# Random path length: 0
#
# Source: Logo, Target: Writing system
# Semantic path length: 7
# Random path length: 0
#
# Source: Motion (physics), Target: Superhero film
# Semantic path length: 6
# Random path length: 0

# %%
human_path_lengths = [len(x) if len(x) else None for x in human_paths]
semantic_path_lengths = [len(x) if len(x) else None for x in semantic_paths]
random_path_lengths = [len(x) if len(x) else None for x in random_paths]

# %% [markdown]
# Now let's put this all into a single dataframe so we can investigate:

# %%
df = pd.DataFrame(data={
    "source": sources,
    "target": targets,
    "human_path": human_paths,
    "semantic_path": semantic_paths,
    "random_path": random_paths,
    "human_path_length": human_path_lengths,
    "semantic_path_length": semantic_path_lengths,
    "random_path_length": random_path_lengths,
})

# %%
df
# Out:
#                              source                                 target  \
# 0                 Romance languages                     Great Barrier Reef
# 1                   Natalie Portman           Proto-Indo-European language
# 2                               IBM                              Human eye
# 3                    Academy Awards             Telecommunications network
# 4                        Folk music                         John Krasinski
# 5                      Kindergarten                            John Calvin
# 6                           Glucose          Nintendo Entertainment System
# 7                            Planet                                BBC One
# 8                    Text messaging                  Resurrection of Jesus
# 9                   Charles Bronson                      Role-playing game
# 10                       Wavelength                         Kelly Clarkson
# 11                        Germanium                                Science
# 12                        The Doors  Nobel Prize in Physiology or Medicine
# 13                             Lead                        DNA replication
# 14       Jacqueline Kennedy Onassis                               Humanism
# 15                       Marco Polo                             Atmosphere
# 16                Diabetes mellitus                            Health care
# 17                        Astronaut                                 Family
# 18                        Minnesota                        Hayley Williams
# 19                            Sheep                              Bruce Lee
# 20                          Fishing                                   Drug
# 21  International Olympic Committee                                  Glass
# 22                       Zhang Ziyi                       Southeast Europe
# 23                             SWAT                          New Testament
# 24                            Wheat                              Doctorate
# 25                      Sarah Palin                                   Ship
# 26                             Tool                               Sunlight
# 27                        Education                  Extraterrestrial life
# 28                             Logo                         Writing system
# 29                 Motion (physics)                         Superhero film
#
#                                            human_path  \
# 0   [Romance languages, Africa, Asia, Pacific Rim,...
# 1   [Natalie Portman, United States nationality la...
# 2   [IBM, Artificial intelligence, Facial recognit...
# 3   [Academy Awards, American Broadcasting Company...
# 4   [Folk music, American folk music, Music of the...
# 5   [Kindergarten, Education in the United States,...
# 6   [Glucose, WHO Model List of Essential Medicine...
# 7   [Planet, Galileo Galilei, Thomas Harriot, Engl...
# 8   [Text messaging, Santa Claus, Easter Bunny, Ea...
# 9   [Charles Bronson, Vigilante, Duel, 1908 Summer...
# 10  [Wavelength, Sound, Musical acoustics, Music, ...
# 11             [Germanium, Chemical element, Science]
# 12  [The Doors, Rock music, Popular music, Pop mus...
# 13           [Lead, Enzyme, Protein, DNA replication]
# 14  [Jacqueline Kennedy Onassis, Academy of Televi...
# 15  [Marco Polo, Fra Mauro map, NASA, Atmosphere o...
# 16  [Diabetes mellitus, Insulin, Diabetes mellitus...
# 17  [Astronaut, Kennedy Space Center, John F. Kenn...
# 18  [Minnesota, United States, Mississippian cultu...
# 19    [Sheep, China, Chinese martial arts, Bruce Lee]
# 20  [Fishing, Kentucky, United States, Drug overdo...
# 21  [International Olympic Committee, Switzerland,...
# 22  [Zhang Ziyi, China, List of countries and depe...
# 23  [SWAT, September 11 attacks, United States, Pr...
# 24  [Wheat, United States, Public university, Doct...
# 25  [Sarah Palin, List of Governors of Alaska, Ala...
# 26                   [Tool, Glasses, Light, Sunlight]
# 27  [Education, Natural science, Science, Astronom...
# 28             [Logo, Greek language, Writing system]
# 29  [Motion (physics), Force, Force (disambiguatio...
#
#                                         semantic_path random_path  \
# 0   [Romance languages, Australia, Great Barrier R...          []
# 1                                                  []          []
# 2   [IBM, Human resources management, Human capita...          []
# 3   [Academy Awards, Streaming service provider, A...          []
# 4                                                  []          []
# 5   [Kindergarten, Paul Monroe, John Dewey, John C...          []
# 6   [Glucose, Reward system, Video game addiction,...          []
# 7                         [Planet, BBC News, BBC One]          []
# 8   [Text messaging, Esprit de corps, Esprit de co...          []
# 9   [Charles Bronson, Combat!, Combat (disambiguat...          []
# 10                                                 []          []
# 11  [Germanium, History of chemistry, Historiograp...          []
# 12                                                 []          []
# 13  [Lead, Homology (chemistry), Homology (disambi...          []
# 14  [Jacqueline Kennedy Onassis, Aristotle Onassis...          []
# 15  [Marco Polo, Shambhala, Soundscape, Ambient mu...          []
# 16    [Diabetes mellitus, Health policy, Health care]          []
# 17  [Astronaut, Asian people, Dougla people, Afro-...          []
# 18                                                 []          []
# 19                                                 []          []
# 20  [Fishing, Bodyboarding, Food, Narcotic, AM-251...          []
# 21  [International Olympic Committee, Quadrennium,...          []
# 22  [Zhang Ziyi, South Korea, South Chungcheong, S...          []
# 23  [SWAT, Christian Parenti, New College of Calif...          []
# 24  [Wheat, Bioenergy, Arborist, Master%27s degree...          []
# 25                                                 []          []
# 26                      [Tool, Solar power, Sunlight]          []
# 27  [Education, Epistemology, Philosophy of life, ...          []
# 28  [Logo, Spencerian Script, Teaching script, Pri...          []
# 29  [Motion (physics), Fictitious force, Edward Ro...          []
#
#     human_path_length  semantic_path_length random_path_length
# 0                   6                   3.0               None
# 1                   7                   NaN               None
# 2                   4                  24.0               None
# 3                   4                  12.0               None
# 4                   8                   NaN               None
# 5                   5                   4.0               None
# 6                   7                   5.0               None
# 7                   7                   3.0               None
# 8                   5                   8.0               None
# 9                  11                   8.0               None
# 10                  6                   NaN               None
# 11                  3                   6.0               None
# 12                  8                   NaN               None
# 13                  4                   7.0               None
# 14                  9                   5.0               None
# 15                 10                  11.0               None
# 16                  7                   3.0               None
# 17                  6                  23.0               None
# 18                  7                   NaN               None
# 19                  4                   NaN               None
# 20                  5                  11.0               None
# 21                  7                  10.0               None
# 22                  5                  11.0               None
# 23                  5                   6.0               None
# 24                  4                   5.0               None
# 25                  7                   NaN               None
# 26                  4                   3.0               None
# 27                  6                   9.0               None
# 28                  3                   7.0               None
# 29                  9                   6.0               None

# %% [markdown]
# And let's save the csv for future analysis!

# %%
df.to_csv("competition_output.csv")
